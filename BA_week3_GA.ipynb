# %% [markdown]
# ### doing as told

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-d1b4927d-e965-4c8d-9228-3c66269dd33e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d1b4927d-e965-4c8d-9228-3c66269dd33e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
pd.max_columns = 15
pd.set_option('display.max_rows', None)

# %%
X_train = pd.read_excel('X_train.xlsx')
X_test = pd.read_excel('X_test.xlsx')
y_train = pd.read_excel('Y_train.xlsx')
y_test = pd.read_excel('Y_test.xlsx')

(X_train.shape, y_train.shape) , (X_test.shape, y_test.shape)
# Out:
# (((212, 14), (212, 2)), ((91, 14), (91, 2)))

# %%
X_train.head()
# Out:
#    Unnamed: 0  age  gender  chest_pain  rest_bps  cholestrol  \
# 0          49   53       0           0       138         234
# 1         171   48       1           1       110         229
# 2         223   56       0           0       200         288
# 3          58   34       1           3       118         182
# 4         154   39       0           2       138         220
#
#    fasting_blood_sugar  rest_ecg  thalach  exer_angina  old_peak  slope  ca  \
# 0                    0         0      160            0       0.0      2   0
# 1                    0         1      168            0       1.0      0   0
# 2                    1         0      133            1       4.0      0   2
# 3                    0         0      174            0       0.0      2   0
# 4                    0         1      152            0       0.0      1   0
#
#    thalassemia
# 0            2
# 1            3
# 2            3
# 3            2
# 4            2

# %%
y_train.head()
# Out:
#    Unnamed: 0  target
# 0          49       1
# 1         171       0
# 2         223       0
# 3          58       1
# 4         154       1

# %%
if X_train.columns[0] == "Unnamed: 0":
  X_train = X_train.drop(columns=["Unnamed: 0"], axis=1)
  X_test = X_test.drop(columns=["Unnamed: 0"], axis=1)
  y_train= y_train.drop(columns=["Unnamed: 0"], axis=1)
  y_test= y_test.drop(columns=["Unnamed: 0"], axis=1)

# %%
X_train.head()
# Out:
#    age  gender  chest_pain  rest_bps  cholestrol  fasting_blood_sugar  \
# 0   53       0           0       138         234                    0
# 1   48       1           1       110         229                    0
# 2   56       0           0       200         288                    1
# 3   34       1           3       118         182                    0
# 4   39       0           2       138         220                    0
#
#    rest_ecg  thalach  exer_angina  old_peak  slope  ca  thalassemia
# 0         0      160            0       0.0      2   0            2
# 1         1      168            0       1.0      0   0            3
# 2         0      133            1       4.0      0   2            3
# 3         0      174            0       0.0      2   0            2
# 4         1      152            0       0.0      1   0            2

# %%
(X_train.shape, y_train.shape) , (X_test.shape, y_test.shape)
# Out:
# (((212, 13), (212, 1)), ((91, 13), (91, 1)))

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(
    random_state=17,
    max_iter=1000
)

model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000, random_state=17)

# %%
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

# %%
print(classification_report(y_train, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.77      0.81        88
#            1       0.85      0.91      0.88       124
#
#     accuracy                           0.85       212
#    macro avg       0.86      0.84      0.85       212
# weighted avg       0.85      0.85      0.85       212

# %%
print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.66      0.76        50
#            1       0.69      0.90      0.78        41
#
#     accuracy                           0.77        91
#    macro avg       0.79      0.78      0.77        91
# weighted avg       0.80      0.77      0.77        91

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, y_pred_test)
# Out:
# array([[33, 17],
#        [ 4, 37]])

# %% [markdown]
# ### for answering questions

# %%
y_train.value_counts(normalize=True) * 100
# Out:
# target
# 1         58.490566
# 0         41.509434
# Name: proportion, dtype: float64

# %%
y_test.value_counts(normalize=True)*100
# Out:
# target
# 0         54.945055
# 1         45.054945
# Name: proportion, dtype: float64

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_train, y_pred_train) * 100
# Out:
# 85.37735849056604

# %%
[[TP, FP],[FN, TN]] = confusion_matrix(y_train, y_pred_train)

# %%
100*TN/(TN+FP)
# Out:
# np.float64(84.9624060150376)

# %%
100*TP/(TP+FN)
# Out:
# np.float64(86.07594936708861)

# %%
[[TP, FP],[FN, TN]] = confusion_matrix(y_test, y_pred_test)

# %%
FP
# Out:
# np.int64(17)

# %%
FN
# Out:
# np.int64(4)

# %%
(TP+TN)/(TP+TN+FP+FN) *100
# Out:
# np.float64(76.92307692307693)

# %%
TP/(TP+FP) * 100
# Out:
# np.float64(66.0)

# %%
TP/(TP+FN) * 100
# Out:
# np.float64(89.1891891891892)
